# %% [markdown]
# # Homework 1 | Handling Data

# %% [markdown]
# A wise figure once said to me: to do anything useful in life, you need to be able to handle 8 gigabytes of option data. The dataset you all have is SPX option data from 1996 to 2023. FUN FACT: I recieved this data as a part of a Summer Reserach Experience I did; the project was paid for, but I found it quite interesting that this SPX daily data costed 3,000 dollars...
#
# In order to really get crack-a-lackin with this dataset, we need a systematic and efficient way to access the contents. Right now the data is stored in a bunch of .zip files on your computers. Your job will be to get the data from a .zip format into a .pkl format (pickle)
#
# Why do this? Well, .zip formats need to be unzipped in order to be accessed. So that's why.
#
# As great thinkers, we will NOT be unzipping the 3,000+ contents of the folder I gave you one by one... Instead, you will make Python do this for you!

# %% [markdown]
# ## Tasks (not necessarily in order)
#
# ### 1. Unzip each of the files and place the result in a seperate folder
#
# ### 2. For each unzipped file, convert it to a pkl format
#
# ### 3. Rename each file --> SPX_OPTIONS_MMDDYYYY
#
# ### 4. Open up a file and play around with the data :)

# %% [markdown]
# ## Your work starts here

# %%
import pandas as pd

# %%
import pandas as pd

# Paste your file path below
txt_file = '/Users/rayanarya/Desktop/TAMID/HW0 and 1/HW1 Data/GI.NA.IVYOPPRCD_202112.txt'

df = pd.read_table(txt_file, sep='\t')
print(df.head())  # Shows the first few rows
# Out:
#    SecurityID      Date   OptionID  Exchange  Currency  Expiration   Strike  \
# 0      108105  20211201  142552109       999       333    20221021  3000000
# 1      108105  20211202  142552109       999       333    20221021  3000000
# 2      108105  20211203  142552109       999       333    20221021  3000000
# 3      108105  20211206  142552109       999       333    20221021  3000000
# 4      108105  20211207  142552109       999       333    20221021  3000000
#
#   CallPut              Symbol   Bid  ...      Vega     Theta  \
# 0       P  SPX 221021P3000000  76.7  ...  695.4796 -148.5575
# 1       P  SPX 221021P3000000  69.9  ...  661.2345 -140.9860
# 2       P  SPX 221021P3000000  77.7  ...  696.9293 -152.6395
# 3       P  SPX 221021P3000000  69.0  ...  654.2104 -142.6037
# 4       P  SPX 221021P3000000  56.1  ...  588.5796 -125.5744
#
#    AdjustmentFactor  ExerciseStyle  SymbolFlag  CalculationPrice  \
# 0                 1              E           1                 M
# ...

# %%
import pandas as pd

# 202112
txt_file = '/Users/rayanarya/Desktop/TAMID/HW0 and 1/HW1 Data/GI.NA.IVYOPPRCD_202112.txt'
pkl_file = '/Users/rayanarya/Desktop/TAMID/HW0 and 1/HW1 Data/GI.NA.IVYOPPRCD_202112.pkl'

df = pd.read_table(txt_file, sep='\t')
df.to_pickle(pkl_file)
print(f"Saved DataFrame to {pkl_file}")
# Out:
# Saved DataFrame to /Users/rayanarya/Desktop/TAMID/HW0 and 1/HW1 Data/GI.NA.IVYOPPRCD_202112.pkl

# %%
# 200302
txt_file = '/Users/rayanarya/Desktop/TAMID/HW0 and 1/HW1 Data/GI.NA.IVYOPPRCD_200302.txt'
pkl_file = '/Users/rayanarya/Desktop/TAMID/HW0 and 1/HW1 Data/GI.NA.IVYOPPRCD_200302.pkl'

df = pd.read_table(txt_file, sep='\t')
df.to_pickle(pkl_file)
print(f"Saved DataFrame to {pkl_file}")
# Out:
# Saved DataFrame to /Users/rayanarya/Desktop/TAMID/HW0 and 1/HW1 Data/GI.NA.IVYOPPRCD_200302.pkl

# %%
200203
txt_file = '/Users/rayanarya/Desktop/TAMID/HW0 and 1/HW1 Data/GI.NA.IVYOPPRCD_200203.txt'
pkl_file = '/Users/rayanarya/Desktop/TAMID/HW0 and 1/HW1 Data/GI.NA.IVYOPPRCD_200203.pkl'

df = pd.read_table(txt_file, sep='\t')
df.to_pickle(pkl_file)
print(f"Saved DataFrame to {pkl_file}")
# Out:
# Saved DataFrame to /Users/rayanarya/Desktop/TAMID/HW0 and 1/HW1 Data/GI.NA.IVYOPPRCD_200203.pkl

# %%
200112
txt_file = '/Users/rayanarya/Desktop/TAMID/HW0 and 1/HW1 Data/GI.NA.IVYOPPRCD_200112.txt'
pkl_file = '/Users/rayanarya/Desktop/TAMID/HW0 and 1/HW1 Data/GI.NA.IVYOPPRCD_200112.pkl'

df = pd.read_table(txt_file, sep='\t')
df.to_pickle(pkl_file)
print(f"Saved DataFrame to {pkl_file}")
# Out:
# Saved DataFrame to /Users/rayanarya/Desktop/TAMID/HW0 and 1/HW1 Data/GI.NA.IVYOPPRCD_200112.pkl

# %%
200007
txt_file = '/Users/rayanarya/Desktop/TAMID/HW0 and 1/HW1 Data/GI.NA.IVYOPPRCD_200007.txt'
pkl_file = '/Users/rayanarya/Desktop/TAMID/HW0 and 1/HW1 Data/GI.NA.IVYOPPRCD_200007.pkl'

df = pd.read_table(txt_file, sep='\t')
df.to_pickle(pkl_file)
print(f"Saved DataFrame to {pkl_file}")
# Out:
# Saved DataFrame to /Users/rayanarya/Desktop/TAMID/HW0 and 1/HW1 Data/GI.NA.IVYOPPRCD_200007.pkl

# %%
199902
txt_file = '/Users/rayanarya/Desktop/TAMID/HW0 and 1/HW1 Data/GI.NA.IVYOPPRCD_199902.txt'
pkl_file = '/Users/rayanarya/Desktop/TAMID/HW0 and 1/HW1 Data/GI.NA.IVYOPPRCD_199902.pkl'

df = pd.read_table(txt_file, sep='\t')
df.to_pickle(pkl_file)
print(f"Saved DataFrame to {pkl_file}")
# Out:
# Saved DataFrame to /Users/rayanarya/Desktop/TAMID/HW0 and 1/HW1 Data/GI.NA.IVYOPPRCD_199902.pkl

# %%
199802
txt_file = '/Users/rayanarya/Desktop/TAMID/HW0 and 1/HW1 Data/GI.NA.IVYOPPRCD_199802.txt'
pkl_file = '/Users/rayanarya/Desktop/TAMID/HW0 and 1/HW1 Data/GI.NA.IVYOPPRCD_199802.pkl'

df = pd.read_table(txt_file, sep='\t')
df.to_pickle(pkl_file)
print(f"Saved DataFrame to {pkl_file}")
# Out:
# Saved DataFrame to /Users/rayanarya/Desktop/TAMID/HW0 and 1/HW1 Data/GI.NA.IVYOPPRCD_199802.pkl

# %%
199802
txt_file = '/Users/rayanarya/Desktop/TAMID/HW0 and 1/HW1 Data/GI.NA.IVYOPPRCD_199705.txt'
pkl_file = '/Users/rayanarya/Desktop/TAMID/HW0 and 1/HW1 Data/GI.NA.IVYOPPRCD_199705.pkl'

df = pd.read_table(txt_file, sep='\t')
df.to_pickle(pkl_file)
print(f"Saved DataFrame to {pkl_file}")
# Out:
# Saved DataFrame to /Users/rayanarya/Desktop/TAMID/HW0 and 1/HW1 Data/GI.NA.IVYOPPRCD_199705.pkl

# %%
import os

folder_path = "/Users/rayanarya/Desktop/TAMID/HW0 and 1/HW1 Data"

for filename in os.listdir(folder_path):
    if filename.endswith(".pkl"):
        date_str = filename.split("_")[-1].replace(".pkl", "") 
        year = date_str[:4]
        month = date_str[4:6]
        day = "01"
        
        new_name = f"SPX_OPTIONS_{month}{day}{year}.pkl"
        old_path = os.path.join(folder_path, filename)
        new_path = os.path.join(folder_path, new_name)
        
        os.rename(old_path, new_path)
        print(f"Renamed {filename} -> {new_name}")
# Out:
# Renamed SPX_OPTIONS_03012002.pkl -> SPX_OPTIONS_20010301.pkl
# Renamed SPX_OPTIONS_02011999.pkl -> SPX_OPTIONS_19010201.pkl
# Renamed SPX_OPTIONS_02011998.pkl -> SPX_OPTIONS_19010201.pkl
# Renamed SPX_OPTIONS_12012021.pkl -> SPX_OPTIONS_20011201.pkl
# Renamed SPX_OPTIONS_02012003.pkl -> SPX_OPTIONS_20010201.pkl
# Renamed SPX_OPTIONS_05011997.pkl -> SPX_OPTIONS_19010501.pkl
# Renamed SPX_OPTIONS_07012000.pkl -> SPX_OPTIONS_20010701.pkl
# Renamed SPX_OPTIONS_12012001.pkl -> SPX_OPTIONS_20011201.pkl

# %% [markdown]
# All that was setup

# %%
import pandas as pd

pkl_file = '/Users/rayanarya/Desktop/TAMID/HW0 and 1/HW1 Data/SPX_OPTIONS_20011201.pkl'
df = pd.read_pickle(pkl_file)
print(df.head())
# Out:
#    SecurityID      Date  OptionID  Exchange  Currency  Expiration   Strike  \
# 0      108105  20011203  20300185       999       333    20020316  1600000
# 1      108105  20011204  20300185       999       333    20020316  1600000
# 2      108105  20011205  20300185       999       333    20020316  1600000
# 3      108105  20011206  20300185       999       333    20020316  1600000
# 4      108105  20011207  20300185       999       333    20020316  1600000
#
#   CallPut  Symbol  Bid  ...      Vega     Theta  AdjustmentFactor  \
# 0       C  SPB.CT  0.0  ...  8.557320 -3.873789                 1
# 1       C  SPB.CT  0.0  ...  8.773734 -3.892523                 1
# 2       C  SPB.CT  0.0  ...  9.208272 -3.899324                 1
# 3       C  SPB.CT  0.0  ...  9.101584 -3.946251                 1
# 4       C  SPB.CT  0.0  ...  8.885295 -3.994661                 1
#
#    ExerciseStyle  SymbolFlag  CalculationPrice  ReferenceExchange  \
# ...

# %% [markdown]
# plot bid+ask/2
